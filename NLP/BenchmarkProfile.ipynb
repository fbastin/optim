# %% [markdown]
# # Profil de performance

# %%
using BenchmarkProfiles
# Out:
# ┌ Info: Precompiling BenchmarkProfiles [ecbce9bc-3e5e-569d-9e29-55181f61f8d0]
# └ @ Base loading.jl:1278

# %% [markdown]
# Exemple d'utilisation issu de https://github.com/JuliaSmoothOptimizers/BenchmarkProfiles.jl

# %%
T = 10 * rand(25,3);  # 25 problems, 3 solvers
performance_profile(T, ["Solver 1", "Solver 2", "Solver 3"], title="Celebrity Deathmatch")

# %% [markdown]
# Référence
#
# E. Dolan and J. Moré, Benchmarking Optimization Software with Performance Profiles, Mathematical Programming 91, pages 201--213, 2002. DOI 10.1007/s101070100263.
